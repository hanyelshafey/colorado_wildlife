# %%
#standard
import geopandas as gpd
import pandas as pd
import seaborn as sns
import fiona


# plot
import matplotlib.pyplot as plt
# %matplotlib inline

#options
sns.set(style='darkgrid')#لتغير استيل الفيجر
pd.set_option('display.max_row',None)

pd.set_option('display.max_columns',None)
# Out:
# /media/hany/Soft/python/data science/spatial data science/wildlife/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# ### Reading data from a shapfile file

# %%
raptors=gpd.read_file('data/Raptor_Nests.shp')

# %%
raptors
# Out:
#      postgis_fi   lat_y_dd   long_x_dd  lastsurvey        recentspec  \
# 0         361.0  40.267502 -104.870872  2012-03-16    Swainsons Hawk
# 1         362.0  40.264321 -104.860255  2012-03-16    Swainsons Hawk
# 2           1.0  38.650081 -105.494251  2014-07-28    Swainsons Hawk
# 3           2.0  40.309574 -104.932604  2011-01-06    Swainsons Hawk
# 4           3.0  40.219343 -104.729246  2014-07-03    Swainsons Hawk
# 5           4.0  40.217638 -104.779386  2011-01-06     Red-tail Hawk
# 6           5.0  40.271203 -104.740819  2011-01-06    Swainsons Hawk
# 7           6.0  40.357587 -104.737632  2011-01-06    Swainsons Hawk
# 8           7.0  40.359660 -104.730698  2011-01-06    Swainsons Hawk
# 9           8.0  40.358919 -104.725179  2011-01-06     Red-tail Hawk
# 10          9.0  40.000189 -104.860463  2011-01-06    Swainsons Hawk
# 11         10.0  40.198163 -104.918726  2011-01-06    Swainsons Hawk
# 12         11.0  40.033635 -104.833716  2011-01-06     Red-tail Hawk
# ...

# %%
sns.relplot(y='lat_y_dd',x='long_x_dd',data=raptors,hue="recentstat",)

# %%
raptors.head()
# Out:
#    postgis_fi   lat_y_dd   long_x_dd  lastsurvey      recentspec  \
# 0       361.0  40.267502 -104.870872  2012-03-16  Swainsons Hawk
# 1       362.0  40.264321 -104.860255  2012-03-16  Swainsons Hawk
# 2         1.0  38.650081 -105.494251  2014-07-28  Swainsons Hawk
# 3         2.0  40.309574 -104.932604  2011-01-06  Swainsons Hawk
# 4         3.0  40.219343 -104.729246  2014-07-03  Swainsons Hawk
#
#       recentstat  Nest_ID                     geometry
# 0  INACTIVE NEST      361  POINT (-104.79595 40.29891)
# 1  INACTIVE NEST      362  POINT (-104.78897 40.22089)
# 2  INACTIVE NEST        1  POINT (-105.50223 38.68694)
# 3  INACTIVE NEST        2  POINT (-104.84889 40.35215)
# 4    ACTIVE NEST        3  POINT (-104.74466 40.18571)

# %%
lastsurvey=sns.relplot(x='lastsurvey',y='Nest_ID',data=raptors.head(50),sizes=(1,5),kind='line')
lastsurvey.fig.autofmt_xdate()

# %%
raptors.plot(column='recentspec',figsize=(10,8),legend=True)
# Out:
# <AxesSubplot:>

# %%
raptors.plot(column='recentstat',figsize=(10,8),legend=True)
# Out:
# <AxesSubplot:>

# %%
raptors.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   postgis_fi  876 non-null    float64
#  1   lat_y_dd    877 non-null    float64
#  2   long_x_dd   877 non-null    float64
#  3   lastsurvey  878 non-null    object
#  4   recentspec  879 non-null    object
#  5   recentstat  879 non-null    object
#  6   Nest_ID     879 non-null    int64
#  7   geometry    879 non-null    geometry
# dtypes: float64(3), geometry(1), int64(1), object(3)
# memory usage: 55.1+ KB

# %%
raptors.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Reading data from a GeoJSON file

# %%
raptors_jsn=gpd.read_file('data/wildlife_raptor.geojson')

# %%
raptors_jsn.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 876 entries, 0 to 875
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   postgis_fid    876 non-null    int64
#  1   lat_y_dd       876 non-null    float64
#  2   long_x_dd      876 non-null    float64
#  3   lastsurvey     876 non-null    object
#  4   recentspecies  876 non-null    object
#  5   recentstatus   876 non-null    object
#  6   Nest_ID        876 non-null    int64
#  7   geometry       876 non-null    geometry
# dtypes: float64(2), geometry(1), int64(2), object(3)
# memory usage: 54.9+ KB

# %%
lastsurvey=sns.relplot(x='long_x_dd',y='lat_y_dd',data=raptors_jsn,sizes=(10,10),style='recentspecies')
lastsurvey.fig.autofmt_xdate()

# %% [markdown]
# ## Reading layers from a multi-layer file
#
# Not fundamentally different from a single layer file, you just need to specify the name of the layer
#
# ### Reading data from a geopackage

# %%
eagles = gpd.read_file("data/DJBasin.gpkg")

# %%
eagles.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1109 entries, 0 to 1108
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   postgis_fi  1109 non-null   int64
#  1   type        1109 non-null   object
#  2   row_width   1109 non-null   float64
#  3   Project     1109 non-null   int64
#  4   geometry    1109 non-null   geometry
# dtypes: float64(1), geometry(1), int64(2), object(1)
# memory usage: 43.4+ KB

# %%
import fiona
fiona.listlayers("data/DJBasin.gpkg")
# Out:
# ['LinearProjects',
#  'BUOWL_Habitat',
#  'BAEA_Nests',
#  'Raptor_nests',
#  'GBH_rookeries',
#  'new_poly',
#  'buowl_ho',
#  'buowl_ho2']

# %%
eagles = gpd.read_file("data/DJBasin.gpkg",layer = "BAEA_Nests")

# %%
eagles.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   postgis_fi  70 non-null     int64
#  1   lat_y_dd    70 non-null     float64
#  2   long_x_dd   70 non-null     float64
#  3   status      70 non-null     object
#  4   nest_id     70 non-null     int64
#  5   geometry    70 non-null     geometry
# dtypes: float64(2), geometry(1), int64(2), object(1)
# memory usage: 3.4+ KB

# %%
eagles.plot(column="status", legend=True, figsize=(10,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# If you want, you can read all of the layers at once into a dictionary that has the layer name as the key

# %%
layers = {} # create an empty dictionary named layers
for lyr in fiona.listlayers("data/DJBasin.gpkg"):
    layers[lyr]=gpd.read_file("data/DJBasin.gpkg",layer=lyr)

# %%
layers["BAEA_Nests"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Read data from a file geodatabase¶
# First lets list the layers in the database

# %%
fiona.listlayers("data/DJBasin.gdb")
# Out:
# ['Burrowing_Owl_Habitat',
#  'Bald_Eagle_Nests',
#  'Raptor_Nests',
#  'Heron_Rookeries',
#  'Linear_Projects']

# %%
Eagle_Nests=gpd.read_file("data/DJBasin.gdb",layer='Bald_Eagle_Nests')

# %%
Eagle_Nests.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   postgis_fi  70 non-null     int64
#  1   lat_y_dd    70 non-null     float64
#  2   long_x_dd   70 non-null     float64
#  3   status      70 non-null     object
#  4   nest_id     70 non-null     int64
#  5   geometry    70 non-null     geometry
# dtypes: float64(2), geometry(1), int64(2), object(1)
# memory usage: 3.4+ KB

# %%
Eagle_Nests.crs
# Out:
# <Projected CRS: EPSG:26913>
# Name: NAD83 / UTM zone 13N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: North America - between 108°W and 102°W - onshore and offshore. Canada - Northwest Territories; Nunavut; Saskatchewan. United States (USA) - Colorado; Montana; Nebraska; New Mexico; North Dakota; Oklahoma; South Dakota; Texas; Wyoming.
# - bounds: (-108.0, 28.98, -102.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 13N
# - method: Transverse Mercator
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Read data from a PostGIS database
#
# To me this is the ultimate combination. Besides the fact that PostGIS will provide the best performance and most features of any storage format, if you know basic Spatial SQL you can do a lot of data manipulation on the fly using SQL b efore the data even comes into GeoPandas and thus you can save yourself a lot of steps when it comes to cleaning data.
#
# Reading data from a PostGIS database requires a database connection object that is easily created with the psycopg modules that we installed along with GeoPandas.
#
# First we import psycopg2

# %%
import psycopg2

# %%
try:
    conn=psycopg2.connect("dbname='korimage_enterprise' user='korimage_reader' host='www.korimageo.com' password='reader'")
    
except:
    print('not connected ')

# %%
eagles = gpd.read_postgis("SELECT gid, lat_y_dd AS latitude, long_x_dd AS longitude, status, nest_id, geom FROM dj_eagle WHERE gid <=70 AND status = 'ACTIVE NEST'", conn)
eagles.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   gid        45 non-null     int64
#  1   latitude   45 non-null     float64
#  2   longitude  45 non-null     float64
#  3   status     45 non-null     object
#  4   nest_id    45 non-null     int64
#  5   geom       45 non-null     geometry
# dtypes: float64(2), geometry(1), int64(2), object(1)
# memory usage: 2.2+ KB

# %%
eagles.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
# %whos
# Out:
# Variable      Type            Data/Info
# ---------------------------------------
# Eagle_Nests   GeoDataFrame        postgis_fi   lat_y_dd<...>510387.399 4437763.519)
# conn          connection      <connection object at 0x7<...>orimageo.com', closed: 0>
# eagles        GeoDataFrame        gid   latitude   long<...>T (-104.85000 39.88531)
# fiona         module          <module 'fiona' from '/me<...>kages/fiona/__init__.py'>
# gpd           module          <module 'geopandas' from <...>s/geopandas/__init__.py'>
# lastsurvey    FacetGrid       <seaborn.axisgrid.FacetGr<...>object at 0x7fe174b90640>
# layers        dict            n=8
# lyr           str             buowl_ho2
# pd            module          <module 'pandas' from '/m<...>ages/pandas/__init__.py'>
# plt           module          <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# psycopg2      module          <module 'psycopg2' from '<...>es/psycopg2/__init__.py'>
# ...

# %%
# %whos GeoDataFrame
# Out:
# Variable      Type            Data/Info
# ---------------------------------------
# Eagle_Nests   GeoDataFrame        postgis_fi   lat_y_dd<...>510387.399 4437763.519)
# eagles        GeoDataFrame        gid   latitude   long<...>T (-104.85000 39.88531)
# raptors       GeoDataFrame         postgis_fi   lat_y_d<...>T (-104.93717 40.24387)
# raptors_jsn   GeoDataFrame         postgis_fid   lat_y_<...>T (-104.84766 39.96975)

# %%
# %who_ls GeoDataFrame
# Out:
# ['Eagle_Nests', 'eagles', 'raptors', 'raptors_jsn']

# %% [markdown]
# ## Advanced reading
# This section will describe some more advanced methods for reading data files
#
# Most of these methods involve ways to read just a subset of the source data based on spatial attributes
#
# ## What is a bounding box and how are they specified?
# Lets start by reading in the raptor data again from a shapefile and viewing it as a map

# %%
raptors=gpd.read_file('data/Raptor_Nests.shp')

# %%
raptors.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
raptors.total_bounds
# Out:
# array([-105.50223,   38.66005, -102.71759,   41.09211])

# %%
aoi=(-105.3,   39.5, -103.70,   40.8)

# %%
raptors=gpd.read_file('data/Raptor_Nests.shp',bbox=aoi)

# %%
raptors.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
counties = gpd.read_file("data/colorado_counties.shp")

# %%
counties.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
counties = gpd.read_file("data/colorado_counties.shp",bbox=raptors)

# %%
counties.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
counties
# Out:
#    OBJECTID COUNTYFP  Shape_Leng  Shape_Area       low    lowmod      LMMI  \
# 0         1      001    4.321021    0.322758  132545.0  231255.0  334950.0
# 1         3      005    3.713979    0.218916  145159.0  250415.0  371560.0
# 2         7      013    2.383373    0.202535   94520.0  121700.0  167445.0
# 3         8      014    1.174635    0.009158    9045.0   17315.0   29050.0
# 4        17      031    2.744229    0.042103  214070.0  330205.0  441065.0
# 5        31      059    2.862683    0.210185  104434.0  192680.0  300285.0
# 6        36      069    3.899824    0.726530   83810.0  134340.0  194105.0
# 7        45      087    2.415281    0.354778    7350.0   13100.0   19145.0
# 8        63      123    5.099761    1.106108   56122.0  100164.0  150579.0
#
#    lowmoduniv  lowmod_pct         NAMELSAD10  \
# 0    467200.0    0.494981       Adams County
# 1    603745.0    0.414769    Arapahoe County
# 2    299850.0    0.405870     Boulder County
# ...

# %%
Boulder_County=counties[counties.NAMELSAD10=='Boulder County']

# %%
Boulder_County.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
boulder_nests= gpd.read_file("data/Raptor_Nests.shp", mask=counties[counties.NAMELSAD10=='Boulder County'])

# %%
boulder_nests.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
boulder_nests.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   postgis_fi  40 non-null     int64
#  1   lat_y_dd    40 non-null     float64
#  2   long_x_dd   40 non-null     float64
#  3   lastsurvey  40 non-null     object
#  4   recentspec  40 non-null     object
#  5   recentstat  40 non-null     object
#  6   Nest_ID     40 non-null     int64
#  7   geometry    40 non-null     geometry
# dtypes: float64(2), geometry(1), int64(2), object(3)
# memory usage: 2.6+ KB

# %%
boulder_nests
# Out:
#     postgis_fi   lat_y_dd   long_x_dd  lastsurvey      recentspec  \
# 0           14  40.126690 -105.020896  2011-01-06  Swainsons Hawk
# 1           62  40.116947 -105.036532  2008-04-25  Swainsons Hawk
# 2          112  40.185024 -105.155517  2008-06-03   Red-tail Hawk
# 3          130  40.182479 -105.021958  2009-02-16  Swainsons Hawk
# 4          154  40.112500 -105.051913  2009-09-21   Red-tail Hawk
# 5          182  40.201741 -104.983809  2010-03-23   Red-tail Hawk
# 6          192  40.061201 -105.005382  2010-10-26   Red-tail Hawk
# 7          293  40.106174 -105.041608  2011-11-07  Swainsons Hawk
# 8          300  40.199408 -104.989102  2011-11-07   Red-tail Hawk
# 9          344  40.084122 -105.042770  2012-02-28   Red-tail Hawk
# 10         374  40.082290 -105.056277  2012-03-27  Swainsons Hawk
# 11         379  40.052378 -105.056543  2012-03-28  Swainsons Hawk
# 12         381  40.061601 -105.070819  2012-04-02   Red-tail Hawk
# ...

# %% [markdown]
# ### read a csv file using the pandas read_csv method

# %%
BAEA_sources = pd.read_csv("data/BAEA_sources.csv")

# %%
BAEA_sources.head(20)
# Out:
#    code                            source
# 0     1  Colorado Fish Wildlife and Parks
# 1     2      US Fish and Wildlife Service
# 2     3                 ABC Environmental
# 3     4                 123 Environmental

# %%
### lets try another

# %%
BAEA_surveys = pd.read_csv("data/BAEA_surveys.csv")

# %%
BAEA_surveys.sort_values('nest')
# Out:
#           id  nest      surveyor        date         result
# 1668  1673.0     1     Dan Smith  2015-07-19  INACTIVE NEST
# 859    864.0     1   Mike Miller  2015-08-28  INACTIVE NEST
# 513    518.0     1     Dan Smith  2015-07-16    ACTIVE NEST
# 1479  1484.0     1   Mike Miller  2015-07-03  INACTIVE NEST
# 1508  1513.0     1   Mike Miller  2015-04-07   FLEDGED NEST
# 1359  1364.0     1     Dan Smith  2015-06-07    ACTIVE NEST
# 838    843.0     1   Mike Miller  2015-04-19    ACTIVE NEST
# 967    972.0     1  George Baker  2015-06-26  INACTIVE NEST
# 577    582.0     1  George Baker  2015-06-15    ACTIVE NEST
# 1810  1815.0     1     Dan Smith  2015-05-05  INACTIVE NEST
# 1860  1865.0     1   Mike Miller  2015-04-02  INACTIVE NEST
# 1765  1770.0     1   Mike Miller  2015-07-24  INACTIVE NEST
# 1133  1138.0     1  George Baker  2015-06-23    ACTIVE NEST
# 1628  1633.0     1   Mike Miller  2015-05-19  INACTIVE NEST
# 1618  1623.0     1   Mike Miller  2015-03-15    ACTIVE NEST
# ...

# %% [markdown]
# We can also select just a subset very easily

# %%
BAEA_surveys[BAEA_surveys["nest"]==14]
# Out:
#           id  nest      surveyor        date         result
# 52      59.0    14     Dan Smith  2015-03-25  INACTIVE NEST
# 215    220.0    14   Mike Miller  2015-03-24    ACTIVE NEST
# 414    419.0    14     Dan Smith  2015-04-05    ACTIVE NEST
# 427    432.0    14   Mike Miller  2015-06-08  INACTIVE NEST
# 552    557.0    14   Mike Miller  2015-07-05   FLEDGED NEST
# 626    631.0    14   Mike Miller  2015-06-12  INACTIVE NEST
# 779    784.0    14     Dan Smith  2015-06-16  INACTIVE NEST
# 798    803.0    14   Mike Miller  2015-03-18   FLEDGED NEST
# 986    991.0    14   Mike Miller  2015-04-16    ACTIVE NEST
# 1028  1033.0    14   Mike Miller  2015-03-17  INACTIVE NEST
# 1258  1263.0    14     Dan Smith  2015-08-02  INACTIVE NEST
# 1344  1349.0    14  George Baker  2015-06-05  INACTIVE NEST
# 1388  1393.0    14  George Baker  2015-08-30  INACTIVE NEST
# 1556  1561.0    14     Dan Smith  2015-06-04  INACTIVE NEST
# 1594  1599.0    14   Mike Miller  2015-05-08    ACTIVE NEST
# ...

# %% [markdown]
# ## Read from excel file
# Not terribly different from read_csv but you can specify a sheet by name
#
# This method does require that the python xlrd module is present in your environment
#
# This method also only reads xls files, not the xlsx file type which has been the norm in excel since 2004. But it is relatively trivial to save an excel file in xls format.

# %%
# !pip install xlrd

# %%
albatross = pd.read_excel("data/wildlife_sightings.xls", sheet_name="albatross")

# %%
albatross
# Out:
#     id   latitude   longitude
# 0    1  39.527924 -105.575747
# 1    2  39.574666 -105.536514
# 2    3  39.217363 -105.374948
# 3    4  39.755457 -105.091596
# 4    5  39.197807 -105.649858
# 5    6  39.642896 -105.326078
# 6    7  39.032123 -105.999383
# 7    8  39.119083 -105.392691
# 8    9  39.874840 -105.207063
# 9   10  39.400908 -105.442039
# 10  11  39.807024 -105.209231
# 11  12  39.901427 -105.900106
# 12  13  39.496948 -105.648963
# 13  14  39.225703 -105.146969
# 14  15  39.179361 -105.300014
# 15  16  39.393826 -105.830052
# 16  17  39.458639 -105.714084
# 17  18  39.095966 -105.519051
# 18  19  39.669779 -105.786503
# 19  20  39.838660 -105.982651
# 20  21  39.852523 -105.029254
# 21  22  39.461515 -105.914187
# 22  23  39.677099 -105.394802
# 23  24  39.510926 -105.212710
# 24  25  39.192025 -105.545456
# 25  26  39.606322 -105.031319
# 26  27  39.200313 -105.352596
# 27  28  39.077793 -105.706396
# 28  29  39.209057 -105.244441
# 29  30  39.137846 -105.835044
# ...

# %%
albatross.plot()#نﻻحظ البلوت للبيانات المكانيه بعد قرائتها من باندا انها لا تمثل خريطه لذلك وجب تحويل البيانات الغير مكانيه لبيانات مكانيه
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Converting non-spatial data to spatial data¶
# You can convert a pandas data frame that has columns for longitude and latitude into a spatial GeoPandas data frame by calling GeoPandas points_from_xy method as below.

# %%
albatross_spatial = gpd.GeoDataFrame(
    albatross, geometry=gpd.points_from_xy(albatross["longitude"], albatross["latitude"]))

# %%
albatross_spatial
# Out:
#     id   latitude   longitude                     geometry
# 0    1  39.527924 -105.575747  POINT (-105.57575 39.52792)
# 1    2  39.574666 -105.536514  POINT (-105.53651 39.57467)
# 2    3  39.217363 -105.374948  POINT (-105.37495 39.21736)
# 3    4  39.755457 -105.091596  POINT (-105.09160 39.75546)
# 4    5  39.197807 -105.649858  POINT (-105.64986 39.19781)
# 5    6  39.642896 -105.326078  POINT (-105.32608 39.64290)
# 6    7  39.032123 -105.999383  POINT (-105.99938 39.03212)
# 7    8  39.119083 -105.392691  POINT (-105.39269 39.11908)
# 8    9  39.874840 -105.207063  POINT (-105.20706 39.87484)
# 9   10  39.400908 -105.442039  POINT (-105.44204 39.40091)
# 10  11  39.807024 -105.209231  POINT (-105.20923 39.80702)
# 11  12  39.901427 -105.900106  POINT (-105.90011 39.90143)
# 12  13  39.496948 -105.648963  POINT (-105.64896 39.49695)
# 13  14  39.225703 -105.146969  POINT (-105.14697 39.22570)
# 14  15  39.179361 -105.300014  POINT (-105.30001 39.17936)
# ...

# %%
# !pip install lxml html5lib BeautifulSoup4

# %%
#import ssl

#ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# NOTE: The return value is a python list of pandas dataframes. One dataframe for each table in the specified web page.

# %%
gdp_list = pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(PPP)_per_capita")

# %%
gdp_list[4]
# Out:
#     Rank                            Country/Territory      Int$       Year
# 0      1                                Liechtenstein  139100.0  2009 est.
# 1      —                                        Macau  123965.0  2019 est.
# 2      2                                       Monaco  115700.0  2015 est.
# 3      3                                   Luxembourg  114482.0  2019 est.
# 4      4                                    Singapore   97341.0  2019 est.
# 5      5                                        Qatar   90044.0  2019 est.
# 6      6                                      Ireland   86781.0  2019 est.
# 7      —                                  Isle of Man   84600.0  2014 est.
# 8      —                                      Bermuda   81798.0  2019 est.
# 9      —                               Cayman Islands   71549.0  2018 est.
# 10     —                             Falkland Islands   70800.0  2015 est.
# ...

# %% [markdown]
# Also note that this will not work on all web pages. In my experience web pages that generate tables dynamically rather than static web pages are especially problematic

# %% [markdown]
# # Many other formats

# %%
#gpd.read_

# %%
#pd.read_

# %%
help(gpd.read_feather)
# Out:
# Help on function _read_feather in module geopandas.io.arrow:
#
# _read_feather(path, columns=None, **kwargs)
#     Load a Feather object from the file path, returning a GeoDataFrame.
#
#     You can read a subset of columns in the file using the ``columns`` parameter.
#     However, the structure of the returned GeoDataFrame will depend on which
#     columns you read:
#
#     * if no geometry columns are read, this will raise a ``ValueError`` - you
#       should use the pandas `read_feather` method instead.
#     * if the primary geometry column saved to this file is not included in
#       columns, the first available geometry column will be set as the geometry
#       column of the returned GeoDataFrame.
#
#     Requires 'pyarrow' >= 0.17.
#
#     .. versionadded:: 0.8
#
#     Parameters
#     ----------
#     path : str, path object
#     columns : list-like of strings, default=None
#         If not None, only these columns will be read from the file.  If
# ...

# %% [markdown]
# ## ####################################################################

# %% [markdown]
# # Write data to file
#
# ## Write shapefile

# %%
buowl_ll=gpd.read_file("data/BUOWL_Habitat.shp")

# %%
buowl_ll
# Out:
#      postgis_fi                                            habitat  \
# 0          15.0                   Ground squirrel-mixed Vegetation
# 1          41.0  Ground squirrel-mixed Vegetation; removed 3/26/14
# 2          42.0  Ground squirrel-mixed Vegetation; removed 3/26/14
# 3          43.0  Ground squirrel-mixed Vegetation; removed 3/26/14
# 4          54.0                           Active Prarie Dog Colony
# 5          56.0                           Active Prarie Dog Colony
# 6          58.0                           Active Prarie Dog Colony
# 7          72.0                   Ground squirrel-mixed Vegetation
# 8          79.0                               Small Animal Burrows
# 9           NaN                           Active Prarie Dog Colony
# 10          NaN                           Active Prarie Dog Colony
# 11        128.0                           Active Prarie Dog Colony
# 12        129.0                           Active Prarie Dog Colony
# ...

# %%
buowl_ll.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 473 entries, 0 to 472
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   postgis_fi  471 non-null    float64
#  1   habitat     459 non-null    object
#  2   hist_occup  469 non-null    object
#  3   recentstat  473 non-null    object
#  4   habitat_id  473 non-null    int64
#  5   active2017  473 non-null    object
#  6   geometry    473 non-null    geometry
# dtypes: float64(1), geometry(1), int64(1), object(4)
# memory usage: 26.0+ KB

# %%
buowl_ll.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
buowl_ll.total_bounds
# Out:
# array([-105.12455,   38.69386, -102.74926,   40.80044])

# %%
aoi=(-105.12455,   39.69386, -103.74926,   40.8004)
buowl_ll=gpd.read_file("data/BUOWL_Habitat.shp",bbox=aoi)
buowl_ll.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
buowl_utm=buowl_ll.to_crs(epsg=26913)

# %%
# %mkdir sh
buowl_utm.to_file('sh/buowl_utm.shp')
# Out:
# mkdir: cannot create directory ‘sh’: File exists

# %%
buowl_utm.crs
# Out:
# <Projected CRS: EPSG:26913>
# Name: NAD83 / UTM zone 13N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: North America - between 108°W and 102°W - onshore and offshore. Canada - Northwest Territories; Nunavut; Saskatchewan. United States (USA) - Colorado; Montana; Nebraska; New Mexico; North Dakota; Oklahoma; South Dakota; Texas; Wyoming.
# - bounds: (-108.0, 28.98, -102.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 13N
# - method: Transverse Mercator
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# You can also easily save just a subset of the dataset

# %%
buowl_utm[buowl_utm["hist_occup"]=='Yes'].to_file("sh/BUOWL_UTM_HO.shp")

# %% [markdown]
# ## Saving as a geopackage layer

# %%
fiona.listlayers("data/DJBasin.gpkg")
# Out:
# ['LinearProjects',
#  'BUOWL_Habitat',
#  'BAEA_Nests',
#  'Raptor_nests',
#  'GBH_rookeries',
#  'new_poly',
#  'buowl_ho',
#  'buowl_ho2']

# %%
buowl_ll[buowl_ll["hist_occup"]=='Yes'].to_file("sh/DJBasin.gpkg", layer = "buowl_ho2", driver = "GPKG")

# %%
help(buowl_ll.to_postgis)
# Out:
# Help on method to_postgis in module geopandas.geodataframe:
#
# to_postgis(name, con, schema=None, if_exists='fail', index=False, index_label=None, chunksize=None, dtype=None) method of geopandas.geodataframe.GeoDataFrame instance
#     Upload GeoDataFrame into PostGIS database.
#
#     This method requires SQLAlchemy and GeoAlchemy2, and a PostgreSQL
#     Python driver (e.g. psycopg2) to be installed.
#
#     Parameters
#     ----------
#     name : str
#         Name of the target table.
#     con : sqlalchemy.engine.Connection or sqlalchemy.engine.Engine
#         Active connection to the PostGIS database.
#     if_exists : {'fail', 'replace', 'append'}, default 'fail'
#         How to behave if the table already exists:
#
#         - fail: Raise a ValueError.
#         - replace: Drop the table before inserting new values.
#         - append: Insert new values to the existing table.
#     schema : string, optional
# ...

# %% [markdown]
# # DataFrames 101
#
# ## Selecting subsets

# %% [markdown]
# ## Referencing series (columns, fields, series, attributes, properties)
#
# Method 1 - dot notation
#
#     df.fieldname
#
# Method 2 - bracket notation
#
#     df['fieldname']
#
# We will be using bracket notation for this course.  I think dot natation is confusing because it could be misinterpreted as a method or property.  Also you can't use variables to refer to column names which limit their usefulness.

# %%
raptors = gpd.read_file("data/Raptor_Nests.shp")
raptors.recentspec
# Out:
# 0        Swainsons Hawk
# 1        Swainsons Hawk
# 2        Swainsons Hawk
# 3        Swainsons Hawk
# 4        Swainsons Hawk
# 5         Red-tail Hawk
# 6        Swainsons Hawk
# 7        Swainsons Hawk
# 8        Swainsons Hawk
# 9         Red-tail Hawk
# 10       Swainsons Hawk
# 11       Swainsons Hawk
# 12        Red-tail Hawk
# 13        Red-tail Hawk
# 14       Swainsons Hawk
# 15       Swainsons Hawk
# 16        Red-tail Hawk
# 17       Swainsons Hawk
# 18        Red-tail Hawk
# 19        Red-tail Hawk
# 20        Red-tail Hawk
# 21       Swainsons Hawk
# 22        Red-tail Hawk
# 23        Red-tail Hawk
# 24       Swainsons Hawk
# 25       Swainsons Hawk
# 26        Red-tail Hawk
# 27        Red-tail Hawk
# 28        Red-tail Hawk
# 29        Red-tail Hawk
# 30       Swainsons Hawk
# 31       Swainsons Hawk
# 32       Swainsons Hawk
# 33        Red-tail Hawk
# 34        Red-tail Hawk
# 35       Swainsons Hawk
# 36        Red-tail Hawk
# 37        Red-tail Hawk
# ...

# %%
raptors['recentspec']
# Out:
# 0        Swainsons Hawk
# 1        Swainsons Hawk
# 2        Swainsons Hawk
# 3        Swainsons Hawk
# 4        Swainsons Hawk
# 5         Red-tail Hawk
# 6        Swainsons Hawk
# 7        Swainsons Hawk
# 8        Swainsons Hawk
# 9         Red-tail Hawk
# 10       Swainsons Hawk
# 11       Swainsons Hawk
# 12        Red-tail Hawk
# 13        Red-tail Hawk
# 14       Swainsons Hawk
# 15       Swainsons Hawk
# 16        Red-tail Hawk
# 17       Swainsons Hawk
# 18        Red-tail Hawk
# 19        Red-tail Hawk
# 20        Red-tail Hawk
# 21       Swainsons Hawk
# 22        Red-tail Hawk
# 23        Red-tail Hawk
# 24       Swainsons Hawk
# 25       Swainsons Hawk
# 26        Red-tail Hawk
# 27        Red-tail Hawk
# 28        Red-tail Hawk
# 29        Red-tail Hawk
# 30       Swainsons Hawk
# 31       Swainsons Hawk
# 32       Swainsons Hawk
# 33        Red-tail Hawk
# 34        Red-tail Hawk
# 35       Swainsons Hawk
# 36        Red-tail Hawk
# 37        Red-tail Hawk
# ...

# %% [markdown]
# You can refer to a column using a variable with bracket notation

# %%
fldname = 'recentstat'
raptors[fldname]
# Out:
# 0           INACTIVE NEST
# 1           INACTIVE NEST
# 2           INACTIVE NEST
# 3           INACTIVE NEST
# 4             ACTIVE NEST
# 5            FLEDGED NEST
# 6           INACTIVE NEST
# 7             ACTIVE NEST
# 8            FLEDGED NEST
# 9           INACTIVE NEST
# 10           FLEDGED NEST
# 11          INACTIVE NEST
# 12          INACTIVE NEST
# 13          INACTIVE NEST
# 14          INACTIVE NEST
# 15            ACTIVE NEST
# 16           FLEDGED NEST
# 17           FLEDGED NEST
# 18          INACTIVE NEST
# 19          INACTIVE NEST
# 20          INACTIVE NEST
# 21          INACTIVE NEST
# 22          INACTIVE NEST
# 23          INACTIVE NEST
# 24          INACTIVE NEST
# 25            ACTIVE NEST
# 26            ACTIVE NEST
# 27          INACTIVE NEST
# 28            ACTIVE NEST
# 29            ACTIVE NEST
# 30          INACTIVE NEST
# 31          INACTIVE NEST
# 32          INACTIVE NEST
# 33          INACTIVE NEST
# 34          INACTIVE NEST
# ...

# %% [markdown]
# But you can't use a variable with dot notation

# %% [markdown]
# You can get a list of column names using the dataframes columns attribute

# %%
raptors.columns
# Out:
# Index(['postgis_fi', 'lat_y_dd', 'long_x_dd', 'lastsurvey', 'recentspec',
#        'recentstat', 'Nest_ID', 'geometry'],
#       dtype='object')

# %% [markdown]
# And knowing this we can loop through the columns and print out the unique values for all string columns that have less than 20 unique values with just a few lines of code

# %%
for fld in raptors.columns:
    if raptors[fld].dtype == 'object' and raptors[fld].nunique()<10:
        print(raptors[fld].name, raptors[fld].unique())
# Out:
# recentspec ['Swainsons Hawk' 'Red-tail Hawk' 'Northern Harrier' 'SWHA' 'RTHA']
# recentstat ['INACTIVE NEST' 'ACTIVE NEST' 'FLEDGED NEST' 'COULD NOT SEE NEST']

# %%
raptors.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   postgis_fi  876 non-null    float64
#  1   lat_y_dd    877 non-null    float64
#  2   long_x_dd   877 non-null    float64
#  3   lastsurvey  878 non-null    object
#  4   recentspec  879 non-null    object
#  5   recentstat  879 non-null    object
#  6   Nest_ID     879 non-null    int64
#  7   geometry    879 non-null    geometry
# dtypes: float64(3), geometry(1), int64(1), object(3)
# memory usage: 55.1+ KB

# %%
raptors['recentspec'].nunique()<20
# Out:
# True

# %%
raptors['recentspec'].value_counts()
# Out:
# Red-tail Hawk       499
# Swainsons Hawk      377
# RTHA                  1
# SWHA                  1
# Northern Harrier      1
# Name: recentspec, dtype: int64

# %% [markdown]
# ### Subset of columns

# %%
raptors.head()
# Out:
#    postgis_fi   lat_y_dd   long_x_dd  lastsurvey      recentspec  \
# 0       361.0  40.267502 -104.870872  2012-03-16  Swainsons Hawk
# 1       362.0  40.264321 -104.860255  2012-03-16  Swainsons Hawk
# 2         1.0  38.650081 -105.494251  2014-07-28  Swainsons Hawk
# 3         2.0  40.309574 -104.932604  2011-01-06  Swainsons Hawk
# 4         3.0  40.219343 -104.729246  2014-07-03  Swainsons Hawk
#
#       recentstat  Nest_ID                     geometry
# 0  INACTIVE NEST      361  POINT (-104.79595 40.29891)
# 1  INACTIVE NEST      362  POINT (-104.78897 40.22089)
# 2  INACTIVE NEST        1  POINT (-105.50223 38.68694)
# 3  INACTIVE NEST        2  POINT (-104.84889 40.35215)
# 4    ACTIVE NEST        3  POINT (-104.74466 40.18571)

# %% [markdown]
# #### يمكن استخلاص داتا فرام من الاصلي بعدد اعمده محدده

# %%
raptors_cols=raptors[["Nest_ID","lastsurvey","recentspec","recentstat"]]

# %%
raptors_cols
# Out:
#      Nest_ID  lastsurvey        recentspec          recentstat
# 0        361  2012-03-16    Swainsons Hawk       INACTIVE NEST
# 1        362  2012-03-16    Swainsons Hawk       INACTIVE NEST
# 2          1  2014-07-28    Swainsons Hawk       INACTIVE NEST
# 3          2  2011-01-06    Swainsons Hawk       INACTIVE NEST
# 4          3  2014-07-03    Swainsons Hawk         ACTIVE NEST
# 5          4  2011-01-06     Red-tail Hawk        FLEDGED NEST
# 6          5  2011-01-06    Swainsons Hawk       INACTIVE NEST
# 7          6  2011-01-06    Swainsons Hawk         ACTIVE NEST
# 8          7  2011-01-06    Swainsons Hawk        FLEDGED NEST
# 9          8  2011-01-06     Red-tail Hawk       INACTIVE NEST
# 10         9  2011-01-06    Swainsons Hawk        FLEDGED NEST
# 11        10  2011-01-06    Swainsons Hawk       INACTIVE NEST
# 12        11  2011-01-06     Red-tail Hawk       INACTIVE NEST
# 13        12  2011-01-06     Red-tail Hawk       INACTIVE NEST
# ...

# %%
# %whos GeoDataFrame
# Out:
# Variable            Type            Data/Info
# ---------------------------------------------
# Boulder_County      GeoDataFrame       OBJECTID COUNTYFP  Sha<...> 39.97412, -105.0577...
# Eagle_Nests         GeoDataFrame        postgis_fi   lat_y_dd<...>510387.399 4437763.519)
# albatross_spatial   GeoDataFrame        id   latitude   longi<...>INT (-105.36700 39.58596)
# boulder_nests       GeoDataFrame        postgis_fi   lat_y_dd<...>T (-105.08037 40.03062)
# buowl_ll            GeoDataFrame         postgis_fi          <...>954, -105.08849 40.0...
# buowl_utm           GeoDataFrame         postgis_fi          <...>29.781, 492448.669 4...
# counties            GeoDataFrame       OBJECTID COUNTYFP  Sha<...> 40.03305, -104.9752...
# eagles              GeoDataFrame        gid   latitude   long<...>T (-104.85000 39.88531)
# raptors             GeoDataFrame         postgis_fi   lat_y_d<...>T (-104.93717 40.24387)
# ...

# %%
# %whos DataFrame # هنا يظهر الraptors_cols في الداتا فرايم لعدم وجود جيوم
# Out:
# Variable       Type         Data/Info
# -------------------------------------
# BAEA_sources   DataFrame       code                  <...>        123 Environmental
# BAEA_surveys   DataFrame              id  nest      s<...>2019-12-30   FLEDGED NEST
# albatross      DataFrame        id   latitude   longi<...>INT (-105.36700 39.58596)
# raptors_cols   DataFrame         Nest_ID  lastsurvey <...> RTHA        FLEDGED NEST

# %%
raptors_cols_geom=raptors[["Nest_ID","lastsurvey","recentspec","geometry"]]

# %%
# %whos DataFrame
# Out:
# Variable       Type         Data/Info
# -------------------------------------
# BAEA_sources   DataFrame       code                  <...>        123 Environmental
# BAEA_surveys   DataFrame              id  nest      s<...>2019-12-30   FLEDGED NEST
# albatross      DataFrame        id   latitude   longi<...>INT (-105.36700 39.58596)
# raptors_cols   DataFrame         Nest_ID  lastsurvey <...> RTHA        FLEDGED NEST

# %%
# %whos GeoDataFrame # here raptors_cols_geom  appear because its conatins geometry field
# Out:
# Variable            Type            Data/Info
# ---------------------------------------------
# Boulder_County      GeoDataFrame       OBJECTID COUNTYFP  Sha<...> 39.97412, -105.0577...
# Eagle_Nests         GeoDataFrame        postgis_fi   lat_y_dd<...>510387.399 4437763.519)
# albatross_spatial   GeoDataFrame        id   latitude   longi<...>INT (-105.36700 39.58596)
# boulder_nests       GeoDataFrame        postgis_fi   lat_y_dd<...>T (-105.08037 40.03062)
# buowl_ll            GeoDataFrame         postgis_fi          <...>954, -105.08849 40.0...
# buowl_utm           GeoDataFrame         postgis_fi          <...>29.781, 492448.669 4...
# counties            GeoDataFrame       OBJECTID COUNTYFP  Sha<...> 40.03305, -104.9752...
# eagles              GeoDataFrame        gid   latitude   long<...>T (-104.85000 39.88531)
# raptors             GeoDataFrame         postgis_fi   lat_y_d<...>T (-104.93717 40.24387)
# ...

# %% [markdown]
# ### Subset by attributes (multiple condition)
#
# * Wrap each condition in parentheses
# * Use & and | rather than **and** and **or**

# %%
raptors[(raptors['recentstat']=='ACTIVE NEST')|(raptors['recentspec']=='Swainsons Hawk')]
# Out:
#      postgis_fi   lat_y_dd   long_x_dd  lastsurvey      recentspec  \
# 0         361.0  40.267502 -104.870872  2012-03-16  Swainsons Hawk
# 1         362.0  40.264321 -104.860255  2012-03-16  Swainsons Hawk
# 2           1.0  38.650081 -105.494251  2014-07-28  Swainsons Hawk
# 3           2.0  40.309574 -104.932604  2011-01-06  Swainsons Hawk
# 4           3.0  40.219343 -104.729246  2014-07-03  Swainsons Hawk
# 6           5.0  40.271203 -104.740819  2011-01-06  Swainsons Hawk
# 7           6.0  40.357587 -104.737632  2011-01-06  Swainsons Hawk
# 8           7.0  40.359660 -104.730698  2011-01-06  Swainsons Hawk
# 10          9.0  40.000189 -104.860463  2011-01-06  Swainsons Hawk
# 11         10.0  40.198163 -104.918726  2011-01-06  Swainsons Hawk
# 14         13.0  40.220769 -104.731024  2014-07-24  Swainsons Hawk
# 15         14.0  40.126690 -105.020896  2011-01-06  Swainsons Hawk
# 17        371.0  40.184320 -104.772750  2012-03-23  Swainsons Hawk
# ...

# %%
raptors[(raptors['recentstat']=='ACTIVE NEST')&(raptors['recentspec']=='Swainsons Hawk')]
# Out:
#      postgis_fi   lat_y_dd   long_x_dd  lastsurvey      recentspec  \
# 4           3.0  40.219343 -104.729246  2014-07-03  Swainsons Hawk
# 7           6.0  40.357587 -104.737632  2011-01-06  Swainsons Hawk
# 15         14.0  40.126690 -105.020896  2011-01-06  Swainsons Hawk
# 25         16.0  40.243589 -104.730385  2011-01-06  Swainsons Hawk
# 40         31.0  40.175037 -104.946548  2011-01-06  Swainsons Hawk
# 45         36.0  40.184210 -104.876609  2011-01-06  Swainsons Hawk
# 51         42.0  40.280158 -105.023386  2008-04-25  Swainsons Hawk
# 88         80.0  40.058600 -104.836715  2008-04-25  Swainsons Hawk
# 94         86.0  40.050671 -104.830275  2008-04-25  Swainsons Hawk
# 105        97.0  40.058384 -104.824545  2008-04-25  Swainsons Hawk
# 128       122.0  40.272105 -104.934651  2014-04-30  Swainsons Hawk
# 133       127.0  40.193263 -104.918913  2014-07-11  Swainsons Hawk
# 135       129.0  40.420177 -104.866610  2009-02-16  Swainsons Hawk
# ...

# %% [markdown]
# ### Subset by coordinates
#
# bounding box using python slice notation

# %%
raptors.plot()
# Out:
# <AxesSubplot:>

# %%
raptors.cx[-105:-104,40:40.5].plot()
# Out:
# <AxesSubplot:>

# %%
raptors=raptors.cx[:-104.3, 39.5:40.6]
raptors.plot()
# Out:
# <AxesSubplot:>

# %%
y_min=raptors['lat_y_dd'].min()
y_max=raptors['lat_y_dd'].max()
y_step=(y_max-y_min)/3
for i in range (3):
    raptors.cx[:,y_min + i*y_step:y_min + (i+1)*y_step].plot()

# %%
y_min=raptors["lat_y_dd"].min()
y_max=raptors["lat_y_dd"].max()
y_step = (y_max-y_min)/3
x_min=raptors["long_x_dd"].min()
x_max=raptors["long_x_dd"].max()
x_step = (x_max-x_min)/3
for y in range(3):
    for x in range(3):
        raptors.cx[x_min + x*x_step:x_min + (x+1)*x_step, y_min + y*y_step:y_min + (y+1)*y_step].plot()
